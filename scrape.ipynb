# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs 
import re

# %%
#Provinsi
provinsi = []
total = []
kd = []  

link = 'https://intranet.atrbpn.go.id/modulWebsite/ajax/daftarPPATProvinsi.php'
resp = requests.get(link)
soup = bs(resp.text, 'html.parser')
tbody = soup.find_all('tbody')
tr = tbody[0].find_all('tr')
for i in range(len(tr)):
    if  tr[i].get('onclick') :
        onclick = tr[i].get('onclick')
        start = onclick.find("('")
        end = onclick.find("')")
        kds = onclick[start + 2 : end]
        kd.append(kds)

        td  = tr[i].find_all('td')

        prov = td[1].text
        provinsi.append(prov)

        jumlah = td[2].text
        total.append(jumlah)
    else:
        break

data = pd.DataFrame(columns=['prov','total','kd'])
data['prov'] = provinsi 
data['total'] = total 
data['kd'] = kd 
data.to_csv('step1.csv', sep='|', index=False)

# %%
#step1
yd = []
kd_v1 = []
prov_v1 = []
kabupaten = [] 
ppat = []
ppats = []

step1 = pd.read_csv('step1.csv', sep='|')
for i in range(len(step1)):
    prov = step1['prov'][i]
    kd = step1['kd'][i]

    link2 = 'https://intranet.atrbpn.go.id/modulWebsite/ajax/daftarPPATKabupaten.php'
    data = {'kd':kd}
    resp = requests.post(link2, data=data)
    soup = bs(resp.text, 'html.parser')

    tbody = soup.find_all('tbody')
    tr = tbody[0].find_all('tr')
    for x in range(len(tr)-1):
        yds = tr[x].get('onclick')
        start = yds.find("('")
        end = yds.find("')")
        yd.append(yds[start + 2:end])

        kd_v1.append(kd)
        prov_v1.append(prov)

        td = tr[x].find_all('td')
        kabupaten.append(td[1].text)
        ppat.append(td[2].text)
        ppats.append(td[3].text)
        #break
    #break 

data = pd.DataFrame(columns=['prov', 'kabupaten', 'ppat', 'ppats', 'kd', 'yd'])
data['prov'] = prov_v1 
data['kabupaten'] = kabupaten
data['ppat'] = ppat 
data['ppats'] = ppats 
data['kd'] = kd_v1
data['yd'] = yd 
data.to_csv('step2.csv', sep='|', index=False)
data
# Out:
#              prov                 kabupaten ppat ppats  \
# 0            Aceh           Kota Banda Aceh   41     8
# 1            Aceh               Kota Sabang    3     3
# 2            Aceh      Kabupaten Aceh Besar   37    20
# 3            Aceh      Kabupaten Aceh Barat   14     6
# 4            Aceh    Kabupaten Aceh Selatan    8    16
# ..            ...                       ...  ...   ...
# 479   Papua Barat      Kabupaten Raja Ampat    2     1
# 480   Papua Barat         Kabupaten Kaimana    2     2
# 481   Papua Barat   Kabupaten Teluk Bintuni    2     0
# 482   Papua Barat        Kabupaten Tambrauw    1     1
# 483   Papua Barat   Kabupaten Teluk Wondama    0     1
#
#                                                     kd  \
# 0    kLdXENTMr96bQ/O+z0Rc/eVztmtwxJsq87YMY17Ub8uOlR...
# 1    kLdXENTMr96bQ/O+z0Rc/eVztmtwxJsq87YMY17Ub8uOlR...
# 2    kLdXENTMr96bQ/O+z0Rc/eVztmtwxJsq87YMY17Ub8uOlR...
# 3    kLdXENTMr96bQ/O+z0Rc/eVztmtwxJsq87YMY17Ub8uOlR...
# 4    kLdXENTMr96bQ/O+z0Rc/eVztmtwxJsq87YMY17Ub8uOlR...
# ..                                                 ...
# 479  ucgsHo0X9dnAAJlURYtClv+IUS45JARc/fKTwn64QxyGii...
# 480  ucgsHo0X9dnAAJlURYtClv+IUS45JARc/fKTwn64QxyGii...
# 481  ucgsHo0X9dnAAJlURYtClv+IUS45JARc/fKTwn64QxyGii...
# 482  ucgsHo0X9dnAAJlURYtClv+IUS45JARc/fKTwn64QxyGii...
# 483  ucgsHo0X9dnAAJlURYtClv+IUS45JARc/fKTwn64QxyGii...
#
#                                                     yd
# 0    /RN+l+0M0vm55ofiPo1iUvdxMM1yy1RW+EdbE1Tmjm3qGj...
# 1    h0WhhhQMt0V85m8JkqAgO9HEeEAcu8IhkJtzQhHJ5NCMzv...
# 2    Ad64JSes8nbDgcfFcgHOg2lceK+n9izWoj2tjLIsEOw5Ga...
# 3    FW5CpsCN/zeMTMq+9QchJMzGimQxqm3CrHKZzjY8fCCl4c...
# 4    wLSYj4osLJP3PRvsmOv8yXTxSS1F5HyjH/5mbQhIKciT/G...
# ..                                                 ...
# 479  XVDEO5NgAY2RN+faoK1v+Bu3ZWDMpigSPMttVX7H/3chNW...
# 480  XVDEO5NgAY2RN+faoK1v+CBNY9Qu33SVv9I886btB56gm2...
# 481  XVDEO5NgAY2RN+faoK1v+I188Q41K7wnDvvzyZz9AAi/lM...
# 482  HSlTHgyPueTHbXAO8jg8poy+4rEGNAgCt450lsGDVYUFQU...
# 483  G+wormtmCIMq/mn85eHlERw03j458kqKROJ+lPfKUsgBLT...
#
# [484 rows x 6 columns]

# %%
#step3
prov = []
kabupaten = []
ppat = []
ppats = [] 
namas = []
emails = []
sks = []
alamats = []
statuss = []

link = 'https://intranet.atrbpn.go.id/modulWebsite/ajax/daftarPPATDetail.php'
step2 = pd.read_csv('step2.csv', sep='|')
for i in range(len(step2)):
    yd = step2['kd'][i]
    kd = step2['yd'][i] 

    data = {
        'kd' : kd,
        'yd' : yd 
    } 

    resp = requests.post(link, data=data) 
    soup = bs(resp.text, 'html.parser')
    table = soup.find_all('table')
    for x in range(len(table)):
        tr = table[x].find_all('tr')

        prov.append(step2['prov'][i])
        kabupaten.append(step2['kabupaten'][i])
        ppat.append(step2['ppat'][i])
        ppats.append(step2['ppats'][i])

        nama = tr[0].find_all('td')[0].find_all('b')[0].text
        namas.append(nama)

        email = tr[1].find_all('td')[1].text
        emails.append(email) 

        sk = re.sub('\r\n', '', tr[2].find_all('td')[1].text).strip()
        sks.append(sk)

        alamat = tr[3].find_all('td')[1].text
        alamats.append(alamat)

        status = tr[4].find_all('td')[1].text
        statuss.append(status)
        #break
    break 

data = pd.DataFrame(columns=['nama', 'email', 'sk', 'alamat', 'status', 'kabupaten', 'prov', 'ppat', 'ppats'])
data['nama'] = namas
data['email'] = emails 
data['sk'] = sks 
data['alamat'] = alamats 
data['status'] = statuss 
data['kabupaten'] = kabupaten
data['prov'] = prov 
data['ppat'] = ppat 
data['ppats'] = ppats 
data.to_csv('nama_ppat.csv', sep='|', index=False)
# Out:
#                         nama                             email  \
# 0              Aditya Caesar               aditkesar@gmail.com
# 1        Ahmad Rifqi Nurilmi           riefkhiemmc@yahoo.co.id
# 2                Akbar Mirza             bysonsniper@gmail.com
# 3                Ali Gunawan               sephine83@gmail.com
# 4                Arie Januar            ariejanuar81@gmail.com
# 5   Arina Novizas Shebubakar         arinashebubakar@gmail.com
# 6                  Asmanizar             asniez_rs@yahoo.co.id
# 7                      Azhar              azharsh_66@yahoo.com
# 8          Cut Ellya Ellyana                ellyacut@gmail.com
# 9                Cut Fediaty           cut.fediaty13@gmail.com
# 10      Dian Sutari Widiyani      diansutariwidiyani@gmail.com
# 21  108.2/SK-11.HP.03/II/2022                     ...
# 22  104/KEP-17.3/III/2011                         ...
# 23  3 - X.A - 2005                                ...
# 24  10/KEP-11.11/XI/2017                          ...
# 25  104/KEP-17.3/III/2011                         ...
# 26  373/KEP-400.20.3/XII/2017                     ...
# 27  9-XVII-PPAT-2008                              ...
# 28  NOMOR 115/SK-400.HR.03.01/III/2019            ...
# 29  108.2/SK-11.HP.03/II/2022                     ...
# 30  108.2/SK-11.HP.03/II/2022                     ...
# 31  6/KEP-400.20.3/I/2018                         ...
# 32  434/KEP-400.20.3/XI/2018                      ...
# 33  SK. KEPALA BADAN PERTANAHAN RI NO. 389/ SK-400...
# 34  NOMOR  311/KEP-400.20.3/XI/2017               ...
# 35  108/KEP-17.3/III/2011                         ...
# 36  216/SK-400.HR.03.01/IV/2019                   ...
# 37  108.2/SK-11.HP.03/II/2022                     ...
# 38  9-XVII-PPAT-2008                              ...
# 39  9/XVII-PPAT-2008                              ...
# 40  14-X.A-2003                                   ...
# 41  434/KEP-400.20.3/XI/2018                      ...
# 42  33/SK-11.HP.03.04/II2023                      ...
# 43  289/KEP-400.20.3/VII/2018                     ...
# 44  2/KEP-17.3/I/2015                             ...
# 45  2/KEP-17.3/I/2015                             ...
# 46  9-XVII-PPAT-2008                              ...
# 47  108.2/SK-11.HP.03/II/2022                     ...
# 48  nomor 42 / KEP-400.20.3 / II / 2018           ...
#
#                                                alamat         status  \
# 0                              Jalan Prof Ali Hasyimi   PPAT | Aktif
# 1           Jalan Tgk. H. Mohd. Daud Beureuh Nomor 80   PPAT | Aktif
# 2   Jl. Prof. Ali Hasyimi, Gp. Pango Raya, Kec. Ul...  PPATS | Aktif
# 3                                Jl. T.P.Polem no. 96   PPAT | Aktif
# 4                               jl. syiah kuala no. 4   PPAT | Aktif
# 5        Jalan T. Nyak Arief, Lorong Thaib Ali No. 01   PPAT | Aktif
# 6   Jalan T. Nyak Arief  No. 42 A, Lamnyong-Lamgug...   PPAT | Aktif
# 7                 Jl. T. Hasan Dek No. 165-Jambo Tape   PPAT | Aktif
# 8                           JLN. SULTAN ISKANDAR MUDA   PPAT | Aktif
# 9   Jl. T. Imuem Lueng Bata No.117, Lueng Bata. Ba...   PPAT | Aktif
# 10                    Jalan KH. Ahmad Dahlan Nomor 12   PPAT | Aktif
# 11                              Jl. Pocut Baren No:51   PPAT | Aktif
# 12                  JL. T. HASAN DEK SIMPANG SURABAYA        PPAT |
# 13                                JL. T.P. NYAK MAKAM   PPAT | Aktif
# 14                                  JALAN T. ISKANDAR   PPAT | Aktif
# 15                    Jalan Tgk. Chik Ditiro Nomor 96   PPAT | Aktif
# 16                  JL. PROF. A MAJID IBRAHIM I NO. 7        PPAT |
# 17       Jalan Sisingamangaraja, simpang tugu lampulo   PPAT | Aktif
# 18                       JL SULTAN ISKANDAR MUDA NO 3   PPAT | Aktif
# 19                Jl. Sultan Hotel, No. 32, Peunayong   PPAT | Aktif
# 20                        jalan T. Nyak Arief nomor 9   PPAT | Aktif
# 21  Jalan Tgk Abd Rahman Meunasah Meucab Komplek A...  PPATS | Aktif
# 23   Kota Banda Aceh   Aceh    41      8
# 24   Kota Banda Aceh   Aceh    41      8
# 25   Kota Banda Aceh   Aceh    41      8
# 26   Kota Banda Aceh   Aceh    41      8
# 27   Kota Banda Aceh   Aceh    41      8
# 28   Kota Banda Aceh   Aceh    41      8
# 29   Kota Banda Aceh   Aceh    41      8
# 30   Kota Banda Aceh   Aceh    41      8
# 31   Kota Banda Aceh   Aceh    41      8
# 32   Kota Banda Aceh   Aceh    41      8
# 33   Kota Banda Aceh   Aceh    41      8
# 34   Kota Banda Aceh   Aceh    41      8
# 35   Kota Banda Aceh   Aceh    41      8
# 36   Kota Banda Aceh   Aceh    41      8
# 37   Kota Banda Aceh   Aceh    41      8
# 38   Kota Banda Aceh   Aceh    41      8
# 39   Kota Banda Aceh   Aceh    41      8
# 40   Kota Banda Aceh   Aceh    41      8
# 41   Kota Banda Aceh   Aceh    41      8
# 42   Kota Banda Aceh   Aceh    41      8
# 43   Kota Banda Aceh   Aceh    41      8
# 44   Kota Banda Aceh   Aceh    41      8
# 45   Kota Banda Aceh   Aceh    41      8
# 46   Kota Banda Aceh   Aceh    41      8
# 47   Kota Banda Aceh   Aceh    41      8
# 48   Kota Banda Aceh   Aceh    41      8

# %%
table = soup.find_all('table')
for x in range(len(table)):
    tr = table[x].find_all('tr')
    nama = tr[0].find_all('td')[0].find_all('b')[0].text
    email = tr[1].find_all('td')[1].text
    sk = tr[2].find_all('td')[1].text 
    alamat = tr[3].find_all('td')[1].text
    status = tr[4].find_all('td')[1].text
    
    break
print(sk)
# Out:
#                   464/KEP-400.20.3/XI/2018
#                   26/11/2018

# %%
re.sub('\r\n', '', tr[2].find_all('td')[1].text).strip()
# Out:
# 'nomor 42 / KEP-400.20.3 / II / 2018                                    05/02/2018'

# %%
url = 'https://intranet.atrbpn.go.id/modulWebsite/ajax/daftarPPATKabupaten.php'
data = 'kLdXENTMr96bQ/O+z0Rc/eVztmtwxJsq87YMY17Ub8uOlRdmb0TQEtg42siqtvjW'
link = 'https://intranet.atrbpn.go.id/modulWebsite/ajax/daftarPPATProvinsi.php'
datas = {'id' : link}
resp = requests.post(url, data=datas) 
resp.text
# Out:
# '<div class="form-group text-center">\r\n  <button type="button" class="btn btn-warning" onclick="kembali()"><i class="fa fa-chevron-left"></i> Kembali</button>\r\n</div>\r\n\r\n<table class="table table-striped table-bordered">\r\n    <thead>\r\n      <tr>\r\n        <th>NO</th>\r\n        <th>KABUPATEN/ KOTA</th>\r\n        <th class="text-center">PPAT</th>\r\n        <th class="text-center">PPATS</th> \r\n      </tr>\r\n    </thead>\r\n    <tbody>\r\n            <tr>\r\n            <td colspan="2">JUMLAH</td> \r\n            <td class="text-center">0</td>\r\n            <td class="text-center">0</td> \r\n          </tr>\r\n    </tbody>\r\n  </table>\r\n  <br />\r\n \r\n\r\n  <script>\r\n    function detail(x){ \r\n    $.ajax({ \r\n      type        : \'POST\', // define the type of HTTP verb we want to use (POST for our form)\r\n      url         : \'ajax/daftarPPATDetail.php\', // the url where we want to POST\r\n      data        : {\'kd\'     : x,\r\n                      \'yd\' : \'\'},  \r\n      beforeSend: function() {\r\n        $("#loading").css("display", "block");\r\n      },\r\n      success: function(data) {   \r\n        $("#ajaxInfo").html(data);   \r\n      },\r\n      complete: function() {\r\n        $("#loading").css("display", "none");\r\n      }\r\n    }); \r\n      \r\n  };\r\n\r\n  function kembali(x){\r\n      $.ajax({ \r\n        type        : \'POST\', // define the type of HTTP verb we want to use (POST for our form)\r\n        url         : \'ajax/daftarPPATProvinsi.php\', // the url where we want to POST\r\n        data        : {\'id\'     : \'NULL\'},  \r\n        beforeSend: function() {\r\n          $("#loading").css("display", "block");\r\n        },\r\n        success: function(data) {   \r\n          $("#ajaxInfo").html(data);   \r\n        },\r\n        complete: function() {\r\n          $("#loading").css("display", "none");\r\n        }\r\n      });  \r\n     } \r\n  </script>\r\n\r\n'

# %%
link = 'https://intranet.atrbpn.go.id/modulWebsite/ajax/daftarPPATProvinsi.php'

# %%
ls = 'https://intranet.atrbpn.go.id/modulWebsite/ajax/daftarPPATKabupaten.php'
data = {
    'kd' : 'kLdXENTMr96bQ/O+z0Rc/eVztmtwxJsq87YMY17Ub8uOlRdmb0TQEtg42siqtvjW'
}
resp = requests.post(ls, data=data)
read = bs(resp.text,'html.parser')
read
# Out:
# <div class="form-group text-center">
# <button class="btn btn-warning" onclick="kembali()" type="button"><i class="fa fa-chevron-left"></i> Kembali</button>
# </div>
# <table class="table table-striped table-bordered">
# <thead>
# <tr>
# <th>NO</th>
# <th>KABUPATEN/ KOTA</th>
# <th class="text-center">PPAT</th>
# <th class="text-center">PPATS</th>
# </tr>
# </thead>
# <tbody>
# <tr onclick="detail('/RN+l+0M0vm55ofiPo1iUvdxMM1yy1RW+EdbE1Tmjm3qGj7n/QJFqbwe4o7zEkEY')" style="cursor: pointer;">
# <td>1.</td>
# <td> Kota Banda Aceh</td>
# <td class="text-center">41</td>
# <td class="text-center">8</td>
# </tr>
# <tr onclick="detail('h0WhhhQMt0V85m8JkqAgO9HEeEAcu8IhkJtzQhHJ5NCMzvtKSW9+5cyY2UXdnQrq')" style="cursor: pointer;">
# <td>2.</td>
# <td> Kota Sabang</td>
# <td class="text-center">3</td>
# <td class="text-center">3</td>
# </tr>
# <tr onclick="detail('Ad64JSes8nbDgcfFcgHOg2lceK+n9izWoj2tjLIsEOw5GabGZBehtu6tetMmoIkO')" style="cursor: pointer;">
# <td>3.</td>
# <td> Kabupaten Aceh Besar</td>
# <td class="text-center">37</td>
# <td class="text-center">20</td>
# </tr>
# <tr onclick="detail('FW5CpsCN/zeMTMq+9QchJMzGimQxqm3CrHKZzjY8fCCl4cuhEMd++UTDNwyvhM1T')" style="cursor: pointer;">
# <td>4.</td>
# <td> Kabupaten Aceh Barat</td>
# <td class="text-center">14</td>
# <td class="text-center">6</td>
# </tr>
# <tr onclick="detail('wLSYj4osLJP3PRvsmOv8yXTxSS1F5HyjH/5mbQhIKciT/GpzKv41PZeoLfd9M4IN')" style="cursor: pointer;">
# <td>5.</td>
# <td> Kabupaten Aceh Selatan</td>
# <td class="text-center">8</td>
# <td class="text-center">16</td>
# </tr>
# <tr onclick="detail('KxF5djzZwwBixvQx3KkdzMEJmLkCCeAwnAjzM9h7ggO6gFGizUCKvsWhlfw5iLra')" style="cursor: pointer;">
# <td>6.</td>
# <td> Kabupaten Pidie</td>
# <td class="text-center">12</td>
# <td class="text-center">1</td>
# </tr>
# <tr onclick="detail('gbBUzwQL7gbCVTo8qUZDcObnB/xMD6WJEYIdztUhZ7uihDx1eDMo09IaRZ2ajC+p')" style="cursor: pointer;">
# <td>7.</td>
# <td> Kabupaten Aceh Utara</td>
# <td class="text-center">6</td>
# <td class="text-center">24</td>
# </tr>
# <tr onclick="detail('e0E1pMjWYGriX7/zoMOL7q0mI9ydDaO34tXRMv5+L6nYip0slqfJVPFzyDQYZpBK')" style="cursor: pointer;">
# <td>8.</td>
# <td> Kabupaten Aceh Timur</td>
# <td class="text-center">13</td>
# <td class="text-center">23</td>
# </tr>
# <tr onclick="detail('Ixhfxg8iuSUv4cmrwn3dfQqU//24c0R+D50M+9VkmYalDUezUnRr8sX31DIgvvol')" style="cursor: pointer;">
# <td>9.</td>
# <td> Kabupaten Aceh Tengah</td>
# <td class="text-center">10</td>
# <td class="text-center">15</td>
# </tr>
# <tr onclick="detail('JJy6zzdhERVHQw69ybawFKW3Sqs40djIdFQx0/5xpViaOsCBmNTadF5/7QB/p2hE')" style="cursor: pointer;">
# <td>10.</td>
# <td> Kabupaten Aceh Tenggara</td>
# <td class="text-center">9</td>
# <td class="text-center">0</td>
# </tr>
# <tr onclick="detail('A8dUNSM1FtVpxE5CRF5e+uKaU3hJDnxXp2nTD+GZvTiqE/jSIfpyb+grmgVT61xt')" style="cursor: pointer;">
# <td>11.</td>
# <td> Kabupaten Bireuen</td>
# <td class="text-center">14</td>
# <td class="text-center">21</td>
# </tr>
# <tr onclick="detail('HxSohwIuQ/WsQQle7mR8fveQ2BRZcZ9F16kSBnNgpKPKE3w+yY4fsG+qY82rsDba')" style="cursor: pointer;">
# <td>12.</td>
# <td> Kabupaten Aceh Singkil</td>
# <td class="text-center">4</td>
# <td class="text-center">3</td>
# </tr>
# <tr onclick="detail('f1NuDOxNTYnUgQ8p6X1dHoZN41mQGHR3UFWVWzB+YMGscLyO7ctjAA5aKVHJZ0nK')" style="cursor: pointer;">
# <td>13.</td>
# <td> Kabupaten Simeulue</td>
# <td class="text-center">1</td>
# <td class="text-center">7</td>
# </tr>
# <tr onclick="detail('Y6ou1Ic9gTP0l5Jnftw8ZBR3XCBNw2PAezApBbQriPWB/rl5k/Sk+mBwDGMW6Rsm')" style="cursor: pointer;">
# <td>14.</td>
# <td> Kabupaten Nagan Raya</td>
# <td class="text-center">8</td>
# <td class="text-center">0</td>
# </tr>
# <tr onclick="detail('J8WMdEgYZZKCWlyBE1ZRDFWgbNR5XU6NHIAARN1A8CViEmC8zAV7Ws/4QLB5DW3x')" style="cursor: pointer;">
# <td>15.</td>
# <td> Kabupaten Aceh Tamiang</td>
# <td class="text-center">13</td>
# <td class="text-center">3</td>
# </tr>
# <tr onclick="detail('kcSCeSkW0W316gX078nuDpYeumvXpCneBOdCi1wSZ2XU8eCkOWjv5Wp35Ikz5IgQ')" style="cursor: pointer;">
# <td>16.</td>
# <td> Kota Lhokseumawe</td>
# <td class="text-center">16</td>
# <td class="text-center">4</td>
# </tr>
# <tr onclick="detail('39FnqH8YhhPerLVB+OVitfUgrWfRaosApe41xoChUNOkQUw+ofJtVtmUKOYfCf7F')" style="cursor: pointer;">
# <td>17.</td>
# <td> Kabupaten Aceh Jaya</td>
# <td class="text-center">4</td>
# <td class="text-center">8</td>
# </tr>
# <tr onclick="detail('doPuDbOQBX3AKoLyb2E82xAg5CHzuqp5WgrqGNdA6nwOnIHcmRngUJhMFAyRs31x')" style="cursor: pointer;">
# <td>18.</td>
# <td> Kota Langsa</td>
# <td class="text-center">15</td>
# <td class="text-center">4</td>
# </tr>
# <tr onclick="detail('tKjLVBCISI/93wU1JI2GKXUFblnzJNEO/qtdiy+n9V0Lk6DsjjmT4YaQPaUzAVk0')" style="cursor: pointer;">
# <td>19.</td>
# <td> Kabupaten Aceh Barat Daya</td>
# <td class="text-center">7</td>
# <td class="text-center">6</td>
# </tr>
# <tr onclick="detail('JJy6zzdhERVHQw69ybawFFLLjlUCcd7lcxqHVmg+WARTxB2FvruKomapml5xAbE3')" style="cursor: pointer;">
# <td>20.</td>
# <td> Kabupaten Gayo Lues</td>
# <td class="text-center">2</td>
# <td class="text-center">2</td>
# </tr>
# <tr onclick="detail('KxF5djzZwwBixvQx3KkdzAddQnOuGXz/fhQYWtRQmeLF0RTHGAnffBcKfAKpvV8k')" style="cursor: pointer;">
# <td>21.</td>
# <td> Kabupaten Pidie Jaya</td>
# <td class="text-center">6</td>
# <td class="text-center">1</td>
# </tr>
# <tr onclick="detail('wLTU9eRn/gNqMVKU3bvDrK2/Ch6Oihntc0q/JwK25TzoV8rrhKrcqwyytUUDfdsr')" style="cursor: pointer;">
# <td>22.</td>
# <td> Kabupaten Bener Meriah</td>
# <td class="text-center">9</td>
# <td class="text-center">0</td>
# </tr>
# <tr onclick="detail('q1ogIjyq23Pmi4mJ06nmYYuK08ASmc0wwWQEeWGsRByUaE71l2md/8uuTcWk93Pn')" style="cursor: pointer;">
# <td>23.</td>
# <td> Kota Subulussalam</td>
# <td class="text-center">3</td>
# <td class="text-center">0</td>
# </tr>
# <tr>
# <td colspan="2">JUMLAH</td>
# <td class="text-center">255</td>
# <td class="text-center">175</td>
# </tr>
# </tbody>
# </table>
# <br/>
# <script>
#     function detail(x){
#     $.ajax({
#       type        : 'POST', // define the type of HTTP verb we want to use (POST for our form)
#       url         : 'ajax/daftarPPATDetail.php', // the url where we want to POST
#       data        : {'kd'     : x,
#                       'yd' : 'kLdXENTMr96bQ/O+z0Rc/eVztmtwxJsq87YMY17Ub8uOlRdmb0TQEtg42siqtvjW'},
#       beforeSend: function() {
#         $("#loading").css("display", "block");
#       },
#       success: function(data) {
#         $("#ajaxInfo").html(data);
#       },
#       complete: function() {
#         $("#loading").css("display", "none");
#       }
#     });
#
#   };
#
#   function kembali(x){
#       $.ajax({
#         type        : 'POST', // define the type of HTTP verb we want to use (POST for our form)
#         url         : 'ajax/daftarPPATProvinsi.php', // the url where we want to POST
#         data        : {'id'     : 'NULL'},
#         beforeSend: function() {
#           $("#loading").css("display", "block");
#         },
#         success: function(data) {
#           $("#ajaxInfo").html(data);
#         },
#         complete: function() {
#           $("#loading").css("display", "none");
#         }
#       });
#      }
#   </script>
